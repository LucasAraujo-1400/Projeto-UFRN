# %%
#####################################################################
########## PROJETO - SISTEMA DE GESTÃO DE ESTACIONAMENTOS ###########
#####################################################################
clientes = {
    # Nome : Email, Idade, Celular
    "Lucas" : ["Lucas@ufrn.edu.br", "20 anos", "(84) 99999-2020"],
    "Mário" : ["Mario@ufrn.edu.br", "19 anos", "(84) 99999-2121"],
    "Pedro" : ["Pedro@ufrn.edu.br", "18 anos", "(84) 99999-2222"],
}

locacoes = {
    # CPF : Nome, E-mail, Idade, Celular
    "11111111111" : ["Lucas Araújo Diniz", "Lucas@ufrn.edu.br", "20 anos", "(84) 99999-2020"],
    "22222222222" : ["Mário dos Santos", "Mario@ufrn.edu.br", "19 anos", "(84) 99999-2121"],
    "33333333333" : ["Pedro Alves Cabral", "Pedro@ufrn.edu.br", "18 anos", "(94) 99999-2222"]
}

vagas = {
    # Placa : Carro, Cor, Nome, Celular
    "ABC1D23" : ["Porsche", "Branco", "Lucas Araújo Diniz", "(84) 99999-2020"],
    "DEF4E56" : ["Ferrari", "Vermelho", "Mário dos Santos", "(84) 99999-2121"],
    "GHI7F89" : ["Lamborghini", "Preto", "Pedro Alves Cabral", "(94) 99999-2222"]
}



resp = ""
while resp != "0":

  print("################################################")
  print("##### Sistema de Gestão de Estacionamentos #####")
  print("################################################")
  print("########       1 - Módulo Clientes      ########")
  print("########       2 - Módulo Locação       ########")
  print("########       3 - Módulo Vagas         ########")
  print("########       4 - Relatório            ########")
  print("########       5 - Sobre o Sistema      ########")
  print("########       0 - Sair                 ########")
  resp = input("######## Escolha uma opção acima: ")
  print()
  if resp == "1":
    print("#########################################################")
    print("############ Você está no Módulo de Clientes ############")
    print("########       1 - Cadastrar Cliente             ########")
    print("########       2 - Exibir dados do Cliente       ########")
    print("########       3 - Alterar dados do Cliente      ########")
    print("########       4 - Remover Cliente               ########")
    print("########       0 - Retornar ao Menu Principal    ########")
    print()
    op_cliente = input("######## Escolha sua opção: ")
    print()
    if op_cliente == "1":
      print("#######################################################")
      print("################## Cadastrar Cliente ##################")
      print("#######################################################")
      print()
      nome = input("Informe seu nome: ")
      print()
      email = input("Informe seu e-mail: ")
      print()
      idade = input("Informe sua idade: ")
      print()
      cel = input("Informe seu número de celular: ")
      print()
      clientes[nome] = [email, idade, cel]
      print("Clientes: ", clientes)
      print("Cliente cadastrado com sucesso! ")
      print()
      print("Tecle <ENTER> para continuar...")
      print()

    elif op_cliente == "2":
        print("#############################################################")
        print("################## Exibir Dados do Cliente ##################")
        print("#############################################################")
        print()
        nome = input("######## Insira o seu nome: ")
        print()
        if nome in clientes:
          print()
          print("######## E-mail: ", clientes[nome][0])
          print("######## Idade: ", clientes[nome][1])
          print("######## Celular: ", clientes[nome][2])
        else:
          print("Cliente não encontrado!")
        print()
        print("Tecle <ENTER> para continuar...")
        print()

    elif op_cliente == "3":
          print("#############################################################")
          print("################## Alterar Dados do Cliente #################")
          print("#############################################################")
          print()
          nome = input("######## Nome: ")
          if nome in clientes:
            print("######## Dados atuais do cliente: ")
            print("######## E-mail: ", clientes[nome][0])
            print("######## Idade: ", clientes[nome][1])
            print("######## Celular: ", clientes[nome][2])
            print()
            print("######## Digite os novos dados para o cliente: ")
            email = input("######## Novo e-mail: ")
            idade = input("######## Nova idade: ")
            cel = input("######## Novo número de celular: ")
            clientes[nome] = [email, idade, cel]
            print()
            print("Dados do cliente alterados com sucesso!")
            print()
            print("Clientes: ", clientes)
            print()
          else:
            print("Não existe nenhum cliente com esse nome!")
          print()
          input("Tecle <ENTER> para continuar...")
          print()

    elif op_cliente == "4":
            print("#############################################################")
            print("################## Remover Dados do Cliente #################")
            print("#############################################################")
            print()
            nome = input("######## Nome: ")
            if nome in clientes:
               print("######## Cliente encontrado:")
               print("######## E-mail: ", clientes[nome][0])
               print("######## Idade: ", clientes[nome][1])
               print("######## Celular: ", clientes[nome][2])
               print()
               confirma = input("######## Deseja excluir esse cliente? S/N ")
               if confirma == "S":
                 del clientes[nome]
                 print("Cliente deletado com sucesso!")
                 print()
                 print("Clientes: ", clientes)
               else:
                 print("Cliente não foi deletaado!")
            else:
             print("Não existe nenhum cliente com esse nome!")
            print()
            input("Tecle <ENTER> para continuar...")
            print()

    elif op_cliente == "0":
      print("###################################################")
      print("###################################################")
      print("###################################################")
      print("#######                                     #######")
      print("#####             Voltando ao                 #####")
      print("#####            Menu Principal...            #####")
      print("#######                                     #######")
      print("###################################################")

    print()
    input("Tecle <ENTER> para continuar...")
    print()




  elif resp == "2":
    print("#########################################################")
    print("############ Você está no Módulo de Locação  ############")
    print("########       1 - Fazer Locação                 ########")
    print("########       2 - Pesquisar Locação             ########")
    print("########       3 - Alterar dados da Locação      ########")
    print("########       4 - Cancelar Locação              ########")
    print("########       0 - Retornar ao Menu Principal    ########")
    print()
    op_locacao = input("######## Escolha sua opção: ")
    print()
    if op_locacao == "1":
      print("#######################################################")
      print("##################  Fazer a Locação  ##################")
      print("#######################################################")
      print()
      cpf = input("########Informe seu CPF: ")
      print()
      nome = input("########Informe seu Nome Completo: ")
      print()
      email = input("########Informe seu e-mail: ")
      print()
      idade = input("########Informe sua idade: ")
      print()
      cel = input("########Informe seu número de celular: ")
      print()
      locacoes[cpf] = [nome, email, idade, cel]
      print("Locações: ", locacoes)
      print("Locação feita com sucesso!")
      print()
      print("Pressione <ENTER> para continuar...")
      print()


    elif op_locacao == "2":
      print("#############################################################")
      print("################## Exibir Dados da Locação ##################")
      print("#############################################################")
      print()
      cpf = input("######## Insira o seu CPF: ")
      print()
      if cpf in locacoes:
        print("######## Nome: ", locacoes[cpf][0])
        print("######## E-mail: ", locacoes[cpf][1])
        print("######## Idade: ", locacoes[cpf][2])
        print("######## Celular: ", locacoes[cpf][3])
      else:
        print("Não existe nenhuma locação com esse CPF!")
      print()
      input("Tecle <ENTER> para continuar...")
      print()

    elif op_locacao == "3":
      print("#############################################################")
      print("################## Alterar Dados da Locação #################")
      print("#############################################################")
      print()
      cpf = input("######## CPF: ")
      print()
      if cpf in locacoes:
        print("######## Dados atuais da locação: ")
        print("######## Nome completo: ", locacoes[cpf][0])
        print("######## E-mail: ", locacoes[cpf][1])
        print("######## Idade: ", locacoes[cpf][2])
        print("######## Celular: ", locacoes[cpf][3])
        print()
        print("######## Digite os novos dados para a locação: ")
        nome = input("######## Novo nome: ")
        email = input("######## Novo e-mail: ")
        idade = input("######## Nova idade: ")
        cel = input("######## Novo número de celular: ")
        locacoes[cpf] = [nome, email, idade, cel]
        print()
        print("Dados da locação alterados com sucesso!")
        print()
        print("Locações: ", locacoes)
        print()
      else:
        print("Não existe nenhuma locação com esse CPF!")
      print()
      input("Tecle <ENTER> para continuar...")
      print()

    elif op_locacao == "4":
        print("#############################################################")
        print("##################    Cancelar a Locação    #################")
        print("#############################################################")
        print()
        cpf = input("######## CPF: ")
        if cpf in locacoes:
          print("######## Locação encontrada:")
          print("######## Nome completo: ", locacoes[cpf][0])
          print("######## E-mail: ", locacoes[cpf][1])
          print("######## Idade: ", locacoes[cpf][2])
          print("######## Celular: ", locacoes[cpf][3])
          print()
          confirma = input("######## Deseja cancelar essa locação? S/N ")
          if confirma == "S":
            del locacoes[cpf]
            print("Locação cancelada com sucesso!")
            print()
            print("Locações: ", locacoes)
          else:
            print("Cancelamento não foi concluído!")
        else:
          print("Não existe nenhuma locação com esse CPF!")
        print()
        input("Tecle <ENTER> para continuar...")
        print()

    elif op_locacao == "0":
      print("###################################################")
      print("###################################################")
      print("###################################################")
      print("#######                                     #######")
      print("#####             Voltando ao                 #####")
      print("#####            Menu Principal...            #####")
      print("#######                                     #######")
      print("###################################################")

    print()
    input("Tecle <ENTER> para continuar...")
    print()


  elif resp == "3":
    print("####################################################")
    print("#########   Você está no Módulo de Vagas   #########")
    print("####################################################")
    print("########       1 - Cadastrar Vaga                ########")
    print("########       2 - Pesquisar Vaga                ########")
    print("########       3 - Alterar dados da Vaga         ########")
    print("########       4 - Desocupar Vaga                ########")
    print("########       0 - Retornar ao Menu Principal    ########")
    print()
    op_vagas = input("######## Escolha sua opção: ")
    if op_vagas == "1":
      print("#######################################################")
      print("##################   Cadastrar Vaga  ##################")
      print("#######################################################")
      print()
      placa = input("########Informe a placa do seu carro: ")
      print()
      carro = input("########Informe o modelo do seu carro: ")
      print()
      cor = input("########Informe a cor do seu carro: ")
      print()
      nome = input("########Informe o seu nome completo: ")
      print()
      cel = input("########Informe seu número de celular: ")
      print()
      vagas[placa] = [carro, cor, nome, cel]
      print("Vagas: ", vagas)
      print("Vaga cadastrada com sucesso!")
      print()
      print("Pressione <ENTER> para continuar...")
      print()


    elif op_vagas == "2":
      print("#############################################################")
      print("################## Exibir Dados da Vaga    ##################")
      print("#############################################################")
      print()
      placa = input("######## Insira a placa do seu carro: ")
      print()
      if placa in vagas:
        print("######## Carro: ", vagas[placa][0])
        print("######## Cor: ", vagas[placa][1])
        print("######## Nome completo: ", vagas[placa][2])
        print("######## Celular: ", vagas[placa][3])
      else:
        print("Não existe nenhuma vaga com essa placa cadastrada!")
      print()
      input("Tecle <ENTER> para continuar...")
      print()

    elif op_vagas == "3":
      print("#############################################################")
      print("##################  Alterar Dados da Vaga   #################")
      print("#############################################################")
      print()
      placa = input("######## Placa: ")
      print()
      if placa in vagas:
        print("######## Dados atuais da vaga cadastrada: ")
        print("######## Carro: ", vagas[placa][0])
        print("######## Cor: ", vagas[placa][1])
        print("######## Nome completo: ", vagas[placa][2])
        print("######## Celular: ", vagas[placa][3])
        print()
        print("######## Digite os novos dados para a vaga: ")
        carro = input("######## Novo carro: ")
        cor = input("######## Nova cor: ")
        nome = input("######## Novo nome: ")
        cel = input("######## Novo número de celular: ")
        vagas[placa] = [carro, cor, nome, cel]
        print()
        print("Dados da vaga alterados com sucesso!")
        print()
        print("Vagas: ", vagas)
        print()
      else:
        print("Não existe nenhuma vaga com essa placa cadastrada!")
      print()
      input("Tecle <ENTER> para continuar...")
      print()

    elif op_vagas == "4":
        print("#############################################################")
        print("##################     Desocupar a Vaga     #################")
        print("#############################################################")
        print()
        placa = input("######## Placa: ")
        if placa in vagas:
          print("######## Vaga encontrada:")
          print("######## Carro: ", vagas[placa][0])
          print("######## Cor: ", vagas[placa][1])
          print("######## Nome completo: ", vagas[placa][2])
          print("######## Celular: ", vagas[placa][3])
          print()
          confirma = input("######## Deseja desocupar essa vaga? S/N ")
          if confirma == "S":
            del vagas[placa]
            print("Vaga desocupada com sucesso!")
            print()
            print("Vagas: ", vagas)
          else:
            print("Desocupamento não foi concluído!")
        else:
          print("Não existe nenhuma vaga com essa placa cadastrada!")
        print()
        input("Tecle <ENTER> para continuar...")
        print()

    elif op_vagas == "0":
      print("###################################################")
      print("###################################################")
      print("###################################################")
      print("#######                                     #######")
      print("#####             Voltando ao                 #####")
      print("#####            Menu Principal...            #####")
      print("#######                                     #######")
      print("###################################################")

    print()
    input("Tecle <ENTER> para continuar...")
    print()

  elif resp == "4":
    print("################################################################")
    print("############### Você está no Módulo de Relatório ###############")
    print("########       1 - Lista de Cliente Cadastrados         ########")
    print("########       2 - Lista de Locações Feitas             ########")
    print("########       3 - Lista de Vagas Ocupadas              ########")
    print("########       0 - Retornar ao Menu Principal           ########")
    print()
    resp2 = input("######## Escolha sua opção: ")
    print()
    print("############################################################")
    print("###############   Isso é apenas um teste!   ################")
    print("###############  Essa funcionalidade ainda  ################")
    print("###############   está sendo desenvolvida!  ################")
    print("############################################################")
    print()

    print()
    print("Retornando ao Menu Principal...")
    input("Tecle <ENTER> para continuar...")
    print()

  elif resp == "5":
    print("######################################################")
    print("########  Você está no Módulo de Informações  ########")


    print("######################################################")
    print("####### <Projeto de Gestão de Estacionamentos> #######")
    print("#######    <-Curso: Sistemas de Informação->   #######")
    print("<---------------------------------------------------->")
    print("#####    ***Aluno que está desenvolvendo:      #######")
    print("#####         * Lucas Araújo Diniz  @UFRN      #######")
    print("<---------------------------------------------------->")
    print("#######  ***Sob orientação do professor:       #######")
    print("#######       *   Flavius Gorgônio             #######")
    print("######################################################")
    print()
    print("Retornando ao Menu Principal...")
    input("Tecle <ENTER> para continuar...")
    print()

  elif resp == "0":
    print("###################################################")
    print("###################################################")
    print("###################################################")
    print("#######                                     #######")
    print("#####            Você encerrou o              #####")
    print("#####           programa, até logo!           #####")
    print("#######                                     #######")
    print("###################################################")

  else:
    print()
    print("###################################################")
    print("########   Você digitou uma opção inválida  #######")
    print("###################################################")
    print("########                                    #######")
    print("#######       Retorne ao menu anterior       ######")
    print("#######          e tente novamente           ######")
    print("########                                    #######")
    print("###################################################")
    print()
    print("Retornando ao Menu Principal...")
    input("Tecle <ENTER> para continuar...")
    print()
# Out:
# ################################################
# ##### Sistema de Gestão de Estacionamentos #####
# ################################################
# ########       1 - Módulo Clientes      ########
# ########       2 - Módulo Locação       ########
# ########       3 - Módulo Vagas         ########
# ########       4 - Relatório            ########
# ########       5 - Sobre o Sistema      ########
# ########       0 - Sair                 ########
# ######## Escolha uma opção acima: 2
#
# #########################################################
# ############ Você está no Módulo de Locação  ############
# ########       1 - Fazer Locação                 ########
# ########       2 - Pesquisar Locação             ########
# ########       3 - Alterar dados da Locação      ########
# ########       4 - Cancelar Locação              ########
# ########       0 - Retornar ao Menu Principal    ########
#
# ######## Escolha sua opção: 2
#
# #############################################################
# ################## Exibir Dados da Locação ##################
# #############################################################
#
# ######## Insira o seu CPF: 11111111111
#
# ######## Nome:  Lucas Araújo Diniz
# ######## E-mail:  Lucas@ufrn.edu.br
# ######## Idade:  20 anos
# ######## Celular:  (84) 99999-2020
#
# Tecle <ENTER> para continuar...
#
#
# Tecle <ENTER> para continuar...
#
# ################################################
# ##### Sistema de Gestão de Estacionamentos #####
# ################################################
# ########       1 - Módulo Clientes      ########
# ########       2 - Módulo Locação       ########
# ########       3 - Módulo Vagas         ########
# ########       4 - Relatório            ########
# ########       5 - Sobre o Sistema      ########
# ########       0 - Sair                 ########
# ######## Escolha uma opção acima: 2
#
# #########################################################
# ############ Você está no Módulo de Locação  ############
# ########       1 - Fazer Locação                 ########
# ########       2 - Pesquisar Locação             ########
# ########       3 - Alterar dados da Locação      ########
# ########       4 - Cancelar Locação              ########
# ########       0 - Retornar ao Menu Principal    ########
#
# ######## Escolha sua opção: 2
#
# #############################################################
# ################## Exibir Dados da Locação ##################
# #############################################################
#
# ######## Insira o seu CPF: 11111111111
#
# ######## Nome:  Lucas Araújo Diniz
# ######## E-mail:  Lucas@ufrn.edu.br
# ######## Idade:  20 anos
# ######## Celular:  (84) 99999-2020
#
# Tecle <ENTER> para continuar...
#
#
# Tecle <ENTER> para continuar...
#
# ################################################
# ##### Sistema de Gestão de Estacionamentos #####
# ################################################
# ########       1 - Módulo Clientes      ########
# ########       2 - Módulo Locação       ########
# ########       3 - Módulo Vagas         ########
# ########       4 - Relatório            ########
# ########       5 - Sobre o Sistema      ########
# ########       0 - Sair                 ########
# ######## Escolha uma opção acima: 2
#
# #########################################################
# ############ Você está no Módulo de Locação  ############
# ########       1 - Fazer Locação                 ########
# ########       2 - Pesquisar Locação             ########
# ########       3 - Alterar dados da Locação      ########
# ########       4 - Cancelar Locação              ########
# ########       0 - Retornar ao Menu Principal    ########
#
# ######## Escolha sua opção: 3
#
# #############################################################
# ################## Alterar Dados da Locação #################
# #############################################################
#
# ######## CPF: 11111111111
#
# ######## Dados atuais da locação:
# ######## Nome completo:  Lucas Araújo Diniz
# ######## E-mail:  Lucas@ufrn.edu.br
# ######## Idade:  20 anos
# ######## Celular:  (84) 99999-2020
#
# ######## Digite os novos dados para a locação:
# ######## Novo nome: rodolfo
# ######## Novo e-mail: akdoskado
# ######## Nova idade: sodkasodkao
# ######## Novo número de celular: sodkaodskao
#
# Dados da locação alterados com sucesso!
#
# Locações:  {'11111111111': ['rodolfo', 'akdoskado', 'sodkasodkao', 'sodkaodskao'], '22222222222': ['Mário dos Santos', 'Mario@ufrn.edu.br', '19 anos', '(84) 99999-2121'], '33333333333': ['Pedro Alves Cabral', 'Pedro@ufrn.edu.br', '18 anos', '(94) 99999-2222']}
#
#
# Tecle <ENTER> para continuar...
#
#
# Tecle <ENTER> para continuar...
#
# ################################################
# ##### Sistema de Gestão de Estacionamentos #####
# ################################################
# ########       1 - Módulo Clientes      ########
# ########       2 - Módulo Locação       ########
# ########       3 - Módulo Vagas         ########
# ########       4 - Relatório            ########
# ########       5 - Sobre o Sistema      ########
# ########       0 - Sair                 ########
# ######## Escolha uma opção acima: 2
#
# #########################################################
# ############ Você está no Módulo de Locação  ############
# ########       1 - Fazer Locação                 ########
# ########       2 - Pesquisar Locação             ########
# ########       3 - Alterar dados da Locação      ########
# ########       4 - Cancelar Locação              ########
# ########       0 - Retornar ao Menu Principal    ########
#
# ######## Escolha sua opção: 4
#
# #############################################################
# ##################    Cancelar a Locação    #################
# #############################################################
#
# ######## CPF: 11111111111
# ######## Locação encontrada:
# ######## Nome completo:  rodolfo
# ######## E-mail:  akdoskado
# ######## Idade:  sodkasodkao
# ######## Celular:  sodkaodskao
#
# ######## Deseja cancelar essa locação? S/N S
# Locação cancelada com sucesso!
#
# Locações:  {'22222222222': ['Mário dos Santos', 'Mario@ufrn.edu.br', '19 anos', '(84) 99999-2121'], '33333333333': ['Pedro Alves Cabral', 'Pedro@ufrn.edu.br', '18 anos', '(94) 99999-2222']}
#
# Tecle <ENTER> para continuar...
#
#
# Tecle <ENTER> para continuar...
#
# ################################################
# ##### Sistema de Gestão de Estacionamentos #####
# ################################################
# ########       1 - Módulo Clientes      ########
# ########       2 - Módulo Locação       ########
# ########       3 - Módulo Vagas         ########
# ########       4 - Relatório            ########
# ########       5 - Sobre o Sistema      ########
# ########       0 - Sair                 ########
# ######## Escolha uma opção acima: 2
#
# #########################################################
# ############ Você está no Módulo de Locação  ############
# ########       1 - Fazer Locação                 ########
# ########       2 - Pesquisar Locação             ########
# ########       3 - Alterar dados da Locação      ########
# ########       4 - Cancelar Locação              ########
# ########       0 - Retornar ao Menu Principal    ########
#
# ######## Escolha sua opção: 0
#
# ###################################################
# ###################################################
# ###################################################
# #######                                     #######
# #####             Voltando ao                 #####
# #####            Menu Principal...            #####
# #######                                     #######
# ###################################################
#
# Tecle <ENTER> para continuar...
#
# ################################################
# ##### Sistema de Gestão de Estacionamentos #####
# ################################################
# ########       1 - Módulo Clientes      ########
# ########       2 - Módulo Locação       ########
# ########       3 - Módulo Vagas         ########
# ########       4 - Relatório            ########
# ########       5 - Sobre o Sistema      ########
# ########       0 - Sair                 ########
# ######## Escolha uma opção acima: 3
#
# ####################################################
# #########   Você está no Módulo de Vagas   #########
# ####################################################
# ########       1 - Cadastrar Vaga                ########
# ########       2 - Pesquisar Vaga                ########
# ########       3 - Alterar dados da Vaga         ########
# ########       4 - Desocupar Vaga                ########
# ########       0 - Retornar ao Menu Principal    ########
#
# ######## Escolha sua opção: 1
# #######################################################
# ##################   Cadastrar Vaga  ##################
# #######################################################
#
# ########Informe a placa do seu carro: kdkdkd
#
# ########Informe o modelo do seu carro: kdkdkd
#
# ########Informe a cor do seu carro: kdkdkd
#
# ########Informe o seu nome completo: kdkdkdk
#
# ########Informe seu número de celular: kdkdkd
#
# Vagas:  {'ABC1D23': ['Porsche', 'Branco', 'Lucas Araújo Diniz', '(84) 99999-2020'], 'DEF4E56': ['Ferrari', 'Vermelho', 'Mário dos Santos', '(84) 99999-2121'], 'GHI7F89': ['Lamborghini', 'Preto', 'Pedro Alves Cabral', '(94) 99999-2222'], 'kdkdkd': ['kdkdkd', 'kdkdkd', 'kdkdkdk', 'kdkdkd']}
# Vaga cadastrada com sucesso!
#
# Pressione <ENTER> para continuar...
#
#
# Tecle <ENTER> para continuar...
#
# ################################################
# ##### Sistema de Gestão de Estacionamentos #####
# ################################################
# ########       1 - Módulo Clientes      ########
# ########       2 - Módulo Locação       ########
# ########       3 - Módulo Vagas         ########
# ########       4 - Relatório            ########
# ########       5 - Sobre o Sistema      ########
# ########       0 - Sair                 ########
# ######## Escolha uma opção acima: 3
#
# ####################################################
# #########   Você está no Módulo de Vagas   #########
# ####################################################
# ########       1 - Cadastrar Vaga                ########
# ########       2 - Pesquisar Vaga                ########
# ########       3 - Alterar dados da Vaga         ########
# ########       4 - Desocupar Vaga                ########
# ########       0 - Retornar ao Menu Principal    ########
#
# ######## Escolha sua opção: 2
# #############################################################
# ################## Exibir Dados da Vaga    ##################
# #############################################################
#
# ######## Insira a placa do seu carro: ABC1D23
#
# ######## Carro:  Porsche
# ######## Cor:  Branco
# ######## Nome completo:  Lucas Araújo Diniz
# ######## Celular:  (84) 99999-2020
#
# Tecle <ENTER> para continuar...
#
#
# Tecle <ENTER> para continuar...
#
# ################################################
# ##### Sistema de Gestão de Estacionamentos #####
# ################################################
# ########       1 - Módulo Clientes      ########
# ########       2 - Módulo Locação       ########
# ########       3 - Módulo Vagas         ########
# ########       4 - Relatório            ########
# ########       5 - Sobre o Sistema      ########
# ########       0 - Sair                 ########
# ######## Escolha uma opção acima: 3
#
# ####################################################
# #########   Você está no Módulo de Vagas   #########
# ####################################################
# ########       1 - Cadastrar Vaga                ########
# ########       2 - Pesquisar Vaga                ########
# ########       3 - Alterar dados da Vaga         ########
# ########       4 - Desocupar Vaga                ########
# ########       0 - Retornar ao Menu Principal    ########
#
# ######## Escolha sua opção: 3
# #############################################################
# ##################  Alterar Dados da Vaga   #################
# #############################################################
#
# ######## Placa: ABC1D23
#
# ######## Dados atuais da vaga cadastrada:
# ######## Carro:  Porsche
# ######## Cor:  Branco
# ######## Nome completo:  Lucas Araújo Diniz
# ######## Celular:  (84) 99999-2020
#
# ######## Digite os novos dados para a vaga:
# ######## Novo carro: KDoskado
# ######## Nova cor: sodkaodksa
# ######## Novo nome: oaksdoaksdo
# ######## Novo número de celular: oksodkas
#
# Dados da vaga alterados com sucesso!
#
# Vagas:  {'ABC1D23': ['KDoskado', 'sodkaodksa', 'oaksdoaksdo', 'oksodkas'], 'DEF4E56': ['Ferrari', 'Vermelho', 'Mário dos Santos', '(84) 99999-2121'], 'GHI7F89': ['Lamborghini', 'Preto', 'Pedro Alves Cabral', '(94) 99999-2222'], 'kdkdkd': ['kdkdkd', 'kdkdkd', 'kdkdkdk', 'kdkdkd']}
#
#
# Tecle <ENTER> para continuar...
#
#
# Tecle <ENTER> para continuar...
#
# ################################################
# ##### Sistema de Gestão de Estacionamentos #####
# ################################################
# ########       1 - Módulo Clientes      ########
# ########       2 - Módulo Locação       ########
# ########       3 - Módulo Vagas         ########
# ########       4 - Relatório            ########
# ########       5 - Sobre o Sistema      ########
# ########       0 - Sair                 ########
# ######## Escolha uma opção acima: 3
#
# ####################################################
# #########   Você está no Módulo de Vagas   #########
# ####################################################
# ########       1 - Cadastrar Vaga                ########
# ########       2 - Pesquisar Vaga                ########
# ########       3 - Alterar dados da Vaga         ########
# ########       4 - Desocupar Vaga                ########
# ########       0 - Retornar ao Menu Principal    ########
#
# ######## Escolha sua opção: 4
# #############################################################
# ##################     Desocupar a Vaga     #################
# #############################################################
#
# ######## Placa: ABC1D23
# ######## Vaga encontrada:
# ######## Carro:  KDoskado
# ######## Cor:  sodkaodksa
# ######## Nome completo:  oaksdoaksdo
# ######## Celular:  oksodkas
#
# ######## Deseja desocupar essa vaga? S/N S
# Vaga desocupada com sucesso!
#
# Vagas:  {'DEF4E56': ['Ferrari', 'Vermelho', 'Mário dos Santos', '(84) 99999-2121'], 'GHI7F89': ['Lamborghini', 'Preto', 'Pedro Alves Cabral', '(94) 99999-2222'], 'kdkdkd': ['kdkdkd', 'kdkdkd', 'kdkdkdk', 'kdkdkd']}
#
# Tecle <ENTER> para continuar...
#
#
# Tecle <ENTER> para continuar...
#
# ################################################
# ##### Sistema de Gestão de Estacionamentos #####
# ################################################
# ########       1 - Módulo Clientes      ########
# ########       2 - Módulo Locação       ########
# ########       3 - Módulo Vagas         ########
# ########       4 - Relatório            ########
# ########       5 - Sobre o Sistema      ########
# ########       0 - Sair                 ########
# ######## Escolha uma opção acima: 3
#
# ####################################################
# #########   Você está no Módulo de Vagas   #########
# ####################################################
# ########       1 - Cadastrar Vaga                ########
# ########       2 - Pesquisar Vaga                ########
# ########       3 - Alterar dados da Vaga         ########
# ########       4 - Desocupar Vaga                ########
# ########       0 - Retornar ao Menu Principal    ########
#
# ######## Escolha sua opção: 0
# ###################################################
# ###################################################
# ###################################################
# #######                                     #######
# #####             Voltando ao                 #####
# #####            Menu Principal...            #####
# #######                                     #######
# ###################################################
#
# Tecle <ENTER> para continuar...
#
# ################################################
# ##### Sistema de Gestão de Estacionamentos #####
# ################################################
# ########       1 - Módulo Clientes      ########
# ########       2 - Módulo Locação       ########
# ########       3 - Módulo Vagas         ########
# ########       4 - Relatório            ########
# ########       5 - Sobre o Sistema      ########
# ########       0 - Sair                 ########
# ######## Escolha uma opção acima: 4
#
# ################################################################
# ############### Você está no Módulo de Relatório ###############
# ########       1 - Lista de Cliente Cadastrados         ########
# ########       2 - Lista de Locações Feitas             ########
# ########       3 - Lista de Vagas Ocupadas              ########
# ########       0 - Retornar ao Menu Principal           ########
#
# ######## Escolha sua opção: 1
#
# ############################################################
# ###############   Isso é apenas um teste!   ################
# ###############  Essa funcionalidade ainda  ################
# ###############   está sendo desenvolvida!  ################
# ############################################################
#
#
# Retornando ao Menu Principal...
# Tecle <ENTER> para continuar...
#
# ################################################
# ##### Sistema de Gestão de Estacionamentos #####
# ################################################
# ########       1 - Módulo Clientes      ########
# ########       2 - Módulo Locação       ########
# ########       3 - Módulo Vagas         ########
# ########       4 - Relatório            ########
# ########       5 - Sobre o Sistema      ########
# ########       0 - Sair                 ########
# ######## Escolha uma opção acima: 5
#
# ######################################################
# ########  Você está no Módulo de Informações  ########
# ######################################################
# ####### <Projeto de Gestão de Estacionamentos> #######
# #######    <-Curso: Sistemas de Informação->   #######
# <---------------------------------------------------->
# #####    ***Aluno que está desenvolvendo:      #######
# #####         * Lucas Araújo Diniz  @UFRN      #######
# <---------------------------------------------------->
# #######  ***Sob orientação do professor:       #######
# #######       *   Flavius Gorgônio             #######
# ######################################################
#
# Retornando ao Menu Principal...
# Tecle <ENTER> para continuar...
#
# ################################################
# ##### Sistema de Gestão de Estacionamentos #####
# ################################################
# ########       1 - Módulo Clientes      ########
# ########       2 - Módulo Locação       ########
# ########       3 - Módulo Vagas         ########
# ########       4 - Relatório            ########
# ########       5 - Sobre o Sistema      ########
# ########       0 - Sair                 ########
# ######## Escolha uma opção acima: 0
#
# ###################################################
# ###################################################
# ###################################################
# #######                                     #######
# #####            Você encerrou o              #####
# #####           programa, até logo!           #####
# #######                                     #######
# ###################################################
